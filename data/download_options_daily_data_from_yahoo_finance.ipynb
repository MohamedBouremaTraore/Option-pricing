# %%
from datetime import date
import importlib
import options_data_utilities
importlib.reload(options_data_utilities)
from options_data_utilities import fetch_all_options

# %%
local_tech_folder = f"Tech_sector_{date.today()}"
local_health_folder = f"Tech_sector_{date.today()}"
local_auto_folder = f"Tech_sector_{date.today()}"
local_finance_folder = f"Tech_sector_{date.today()}"

technology_sector_companies_tickers = ["AAPL", "MSFT", "AMZN", "GOOGL", "META"]
automobile_sector_companies_tickers = ["TSLA", "GM", "F", "RIVN", "LCID"]

# %%
for symbol in technology_sector_companies_tickers:
    output_dir = "./daily historical datas/Technology/" + local_tech_folder

    calls_df, puts_df = fetch_all_options(
        symbol=symbol,
        output_dir=output_dir,
        pause=0.5
    )

    print("Download completed!")
    print(f"Calls shape: {calls_df.shape}")
    print(f"Puts shape: {puts_df.shape}")
# Out:
# INFO:utils:AAPL: 22 expiries found
# INFO:utils:Saved calls to ./daily historical datas/Tech_sector_2026-04-19\AAPL_calls_2026-04-19.csv
# INFO:utils:Saved puts to ./daily historical datas/Tech_sector_2026-04-19\AAPL_puts_2026-04-19.csv
# INFO:utils:All option data for AAPL saved in ./daily historical datas/Tech_sector_2026-04-19
# INFO:utils:MSFT: 22 expiries found
# Download completed!
# Calls shape: (1225, 15)
# Puts shape: (1085, 15)
# INFO:utils:Saved calls to ./daily historical datas/Tech_sector_2026-04-19\MSFT_calls_2026-04-19.csv
# INFO:utils:Saved puts to ./daily historical datas/Tech_sector_2026-04-19\MSFT_puts_2026-04-19.csv
# INFO:utils:All option data for MSFT saved in ./daily historical datas/Tech_sector_2026-04-19
# INFO:utils:AMZN: 23 expiries found
# Download completed!
# Calls shape: (1526, 15)
# Puts shape: (1414, 15)
# INFO:utils:Saved calls to ./daily historical datas/Tech_sector_2026-04-19\AMZN_calls_2026-04-19.csv
# ...

# %%
for symbol in automobile_sector_companies_tickers:
    output_dir = "./daily historical datas/Automobile/" + local_auto_folder

    calls_df, puts_df = fetch_all_options(
        symbol=symbol,
        output_dir=output_dir,
        pause=0.5
    )

    print("Download completed!")
    print(f"Calls shape: {calls_df.shape}")
    print(f"Puts shape: {puts_df.shape}")
