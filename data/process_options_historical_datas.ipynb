# %% [markdown]
# ##### Define variables

# %%
import pandas as pd
pd.set_option('display.float_format', '{:.5f}'.format)
pd.set_option('display.max_columns', None)
import time
import importlib
import utilities
importlib.reload(utilities)
from utilities import *
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'journal2 (Python 3.13.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
folder = './daily historical datas/'
technology = "Technology"
automobile = "Automobile"

# %%
Technology = { "AAPL": pd.DataFrame(), "AMZN": pd.DataFrame(), "GOOGL": pd.DataFrame(), "META": pd.DataFrame(), "MSFT": pd.DataFrame() }
Automobile = { "F": pd.DataFrame(), "GM": pd.DataFrame(), "LCID": pd.DataFrame(), "RIVN": pd.DataFrame(), "TSLA": pd.DataFrame() }

# %%
TechnologyUnderlying = [ "AAPL", "AMZN", "GOOGL", "META", "MSFT" ]
AutomobileUnderlying = [ "F", "GM", "LCID", "RIVN", "TSLA" ]

# %% [markdown]
# ##### Merge options dataily data and remove duplicate rows

# %%
for ticker, OptionsData in Technology.items():
  df_final = fusionner_fichiers(folder, technology, ticker)
  df_final = remove_duplicates(df_final)
  Technology[ticker]= df_final
# Out:
# INFO:utilities:174 files found for keyword: aapl
# ['./daily historical datas/Technology\\Tech_sector_2025-09-12\\AAPL_calls_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-12\\AAPL_puts_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\AAPL_calls_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\AAPL_puts_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\AAPL_calls_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\AAPL_puts_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\AAPL_calls_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\AAPL_puts_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\AAPL_calls_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\AAPL_puts_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\AAPL_calls_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\AAPL_puts_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\AAPL_calls_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\AAPL_puts_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\AAPL_calls_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\AAPL_puts_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\AAPL_calls_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\AAPL_puts_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\AAPL_calls_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\AAPL_puts_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\AAPL_calls_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\AAPL_puts_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\AAPL_calls_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\AAPL_puts_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\AAPL_calls_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\AAPL_puts_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\AAPL_calls_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\AAPL_puts_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\AAPL_calls_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\AAPL_puts_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\AAPL_calls_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\AAPL_puts_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\AAPL_calls_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\AAPL_puts_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\AAPL_calls_all_for_2025-09-23.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\AAPL_puts_all_for_2025-09-23.csv', './daily  ...
# INFO:utilities:Merged dataset shape: (192224, 16)
# INFO:utilities:Removed 84445 duplicates
# INFO:utilities:174 files found for keyword: amzn
# ['./daily historical datas/Technology\\Tech_sector_2025-09-12\\AMZN_calls_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-12\\AMZN_puts_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\AMZN_calls_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\AMZN_puts_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\AMZN_calls_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\AMZN_puts_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\AMZN_calls_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\AMZN_puts_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\AMZN_calls_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\AMZN_puts_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\AMZN_calls_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\AMZN_puts_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\AMZN_calls_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\AMZN_puts_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\AMZN_calls_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\AMZN_puts_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\AMZN_calls_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\AMZN_puts_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\AMZN_calls_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\AMZN_puts_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\AMZN_calls_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\AMZN_puts_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\AMZN_calls_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\AMZN_puts_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\AMZN_calls_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\AMZN_puts_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\AMZN_calls_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\AMZN_puts_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\AMZN_calls_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\AMZN_puts_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\AMZN_calls_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\AMZN_puts_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\AMZN_calls_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\AMZN_puts_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\AMZN_calls_all_for_2025-09-23.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\AMZN_puts_all_for_2025-09-23.csv', './daily  ...
# INFO:utilities:Merged dataset shape: (170543, 16)
# INFO:utilities:Removed 52698 duplicates
# INFO:utilities:174 files found for keyword: googl
# ['./daily historical datas/Technology\\Tech_sector_2025-09-12\\GOOGL_calls_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-12\\GOOGL_puts_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\GOOGL_calls_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\GOOGL_puts_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\GOOGL_calls_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\GOOGL_puts_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\GOOGL_calls_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\GOOGL_puts_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\GOOGL_calls_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\GOOGL_puts_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\GOOGL_calls_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\GOOGL_puts_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\GOOGL_calls_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\GOOGL_puts_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\GOOGL_calls_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\GOOGL_puts_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\GOOGL_calls_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\GOOGL_puts_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\GOOGL_calls_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\GOOGL_puts_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\GOOGL_calls_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\GOOGL_puts_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\GOOGL_calls_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\GOOGL_puts_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\GOOGL_calls_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\GOOGL_puts_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\GOOGL_calls_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\GOOGL_puts_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\GOOGL_calls_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\GOOGL_puts_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\GOOGL_calls_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\GOOGL_puts_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\GOOGL_calls_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\GOOGL_puts_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\GOOGL_calls_all_for_2025-09-23.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\GOOGL_put ...
# INFO:utilities:Merged dataset shape: (220978, 16)
# INFO:utilities:Removed 94565 duplicates
# INFO:utilities:174 files found for keyword: meta
# ['./daily historical datas/Technology\\Tech_sector_2025-09-12\\META_calls_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-12\\META_puts_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\META_calls_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\META_puts_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\META_calls_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\META_puts_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\META_calls_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\META_puts_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\META_calls_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\META_puts_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\META_calls_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\META_puts_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\META_calls_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\META_puts_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\META_calls_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\META_puts_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\META_calls_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\META_puts_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\META_calls_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\META_puts_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\META_calls_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\META_puts_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\META_calls_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\META_puts_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\META_calls_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\META_puts_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\META_calls_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\META_puts_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\META_calls_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\META_puts_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\META_calls_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\META_puts_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\META_calls_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\META_puts_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\META_calls_all_for_2025-09-23.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\META_puts_all_for_2025-09-23.csv', './daily  ...
# INFO:utilities:Merged dataset shape: (403544, 16)
# INFO:utilities:Removed 208241 duplicates
# INFO:utilities:174 files found for keyword: msft
# ['./daily historical datas/Technology\\Tech_sector_2025-09-12\\MSFT_calls_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-12\\MSFT_puts_all_for_2025-09-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\MSFT_calls_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-15\\MSFT_puts_all_for_2025-09-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\MSFT_calls_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-16\\MSFT_puts_all_for_2025-09-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\MSFT_calls_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-17\\MSFT_puts_all_for_2025-09-17.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\MSFT_calls_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-18\\MSFT_puts_all_for_2025-09-18.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\MSFT_calls_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\MSFT_puts_all_for_2025-09-19.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\MSFT_calls_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-06\\MSFT_puts_all_for_2026-01-06.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\MSFT_calls_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-07\\MSFT_puts_all_for_2026-01-07.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\MSFT_calls_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-08\\MSFT_puts_all_for_2026-01-08.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\MSFT_calls_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-09\\MSFT_puts_all_for_2026-01-09.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\MSFT_calls_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-12\\MSFT_puts_all_for_2026-01-12.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\MSFT_calls_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-13\\MSFT_puts_all_for_2026-01-13.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\MSFT_calls_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-14\\MSFT_puts_all_for_2026-01-14.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\MSFT_calls_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-15\\MSFT_puts_all_for_2026-01-15.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\MSFT_calls_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-16\\MSFT_puts_all_for_2026-01-16.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\MSFT_calls_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-19\\Tech_sector_2026-01-20\\MSFT_puts_all_for_2026-01-20.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\MSFT_calls_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-22\\MSFT_puts_all_for_2025-09-22.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\MSFT_calls_all_for_2025-09-23.csv', './daily historical datas/Technology\\Tech_sector_2025-09-23\\MSFT_puts_all_for_2025-09-23.csv', './daily  ...
# INFO:utilities:Merged dataset shape: (249749, 16)
# INFO:utilities:Removed 118892 duplicates

# %%
for ticker, OptionsData in Automobile.items():
  df_final = fusionner_fichiers(folder, automobile, ticker)
  df_final = remove_duplicates(df_final)
  Automobile[ticker]= df_final
# Out:
# INFO:utilities:870 files found for keyword: f
# ['./daily historical datas/Automobile\\Auto_sector_2025-09-12\\F_calls_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\F_puts_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\GM_calls_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\GM_puts_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\LCID_calls_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\LCID_puts_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\RIVN_calls_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\RIVN_puts_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\TSLA_calls_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\TSLA_puts_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\F_calls_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\F_puts_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\GM_calls_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\GM_puts_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\LCID_calls_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\LCID_puts_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\RIVN_calls_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\RIVN_puts_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\TSLA_calls_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\TSLA_puts_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\F_calls_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\F_puts_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\GM_calls_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\GM_puts_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\LCID_calls_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\LCID_puts_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\RIVN_calls_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\RIVN_puts_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\TSLA_calls_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\TSLA_puts_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\F_calls_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\F_puts_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\GM_calls_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\GM_puts_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\LCID_calls_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\LCID_puts_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\RIVN_calls_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\RIVN_puts_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\TSLA_calls_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\TSLA_puts_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-18\\F_calls_all_for_2025-09-18.csv', './daily historical datas/Automobile\\Auto_s ...
# INFO:utilities:Merged dataset shape: (662613, 16)
# INFO:utilities:Removed 287892 duplicates
# INFO:utilities:174 files found for keyword: gm
# ['./daily historical datas/Automobile\\Auto_sector_2025-09-12\\GM_calls_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-12\\GM_puts_all_for_2025-09-12.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\GM_calls_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-15\\GM_puts_all_for_2025-09-15.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\GM_calls_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-16\\GM_puts_all_for_2025-09-16.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\GM_calls_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-17\\GM_puts_all_for_2025-09-17.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-18\\GM_calls_all_for_2025-09-18.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-18\\GM_puts_all_for_2025-09-18.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-19\\GM_calls_all_for_2025-09-19.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-19\\GM_puts_all_for_2025-09-19.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-22\\GM_calls_all_for_2025-09-22.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-22\\GM_puts_all_for_2025-09-22.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-23\\GM_calls_all_for_2025-09-23.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-23\\GM_puts_all_for_2025-09-23.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-24\\GM_calls_all_for_2025-09-24.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-24\\GM_puts_all_for_2025-09-24.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-25\\GM_calls_all_for_2025-09-25.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-25\\GM_puts_all_for_2025-09-25.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-26\\GM_calls_all_for_2025-09-26.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-26\\GM_puts_all_for_2025-09-26.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-29\\GM_calls_all_for_2025-09-29.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-29\\GM_puts_all_for_2025-09-29.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-30\\GM_calls_all_for_2025-09-30.csv', './daily historical datas/Automobile\\Auto_sector_2025-09-30\\GM_puts_all_for_2025-09-30.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-01\\GM_calls_all_for_2025-10-01.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-01\\GM_puts_all_for_2025-10-01.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-02\\GM_calls_all_for_2025-10-02.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-02\\GM_puts_all_for_2025-10-02.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-03\\GM_calls_all_for_2025-10-03.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-03\\GM_puts_all_for_2025-10-03.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-06\\GM_calls_all_for_2025-10-06.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-06\\GM_puts_all_for_2025-10-06.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-07\\GM_calls_all_for_2025-10-07.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-07\\GM_puts_all_for_2025-10-07.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-08\\GM_calls_all_for_2025-10-08.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-08\\GM_puts_all_for_2025-10-08.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-09\\GM_calls_all_for_2025-10-09.csv', './daily historical datas/Automobile\\Auto_sector_2025-10
csv', './daily historical datas/Automobile\\Auto_sector_2025-10-09\\TSLA_puts_all_for_2025-10-09.csv', './daily historical datas/Automobile\\Auto_sector_2025-10-10\\TSLA_calls_all_for_2025-10-10.csv', ' ...
# INFO:utilities:Merged dataset shape: (421080, 16)
# INFO:utilities:Removed 156313 duplicates

# %% [markdown]
# ##### Combine all options data in single dataset

# %%
optionsData = pd.DataFrame()

for ticker, dataframe in Automobile.items():
  optionsData = merged_df = pd.concat([optionsData, dataframe], ignore_index=True)

for ticker, dataframe in Technology.items():
  optionsData = merged_df = pd.concat([optionsData, dataframe], ignore_index=True)

# %%
len(optionsData)
# Out:
# 2114582

# %%
optionsData = remove_duplicates(optionsData)
# Out:
# INFO:utilities:Removed 579745 duplicates

# %%
len(optionsData)
# Out:
# 1534837

# %% [markdown]
# ##### Preprocess options dataset

# %%
optionsData['optionType'] = optionsData['source_file'].str.contains('call').replace({True:'call', False:'put'})
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_36240\262952590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optionsData['optionType'] = optionsData['source_file'].str.contains('call').replace({True:'call', False:'put'})

# %%
optionsData['date'] = optionsData['lastTradeDate']
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_36240\847214949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optionsData['date'] = optionsData['lastTradeDate']

# %%
optionsData['date'] = pd.to_datetime(optionsData['date']).dt.date
optionsData['date'] = pd.to_datetime(optionsData['date'])
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_36240\4140904624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optionsData['date'] = pd.to_datetime(optionsData['date']).dt.date
# C:\Users\H P\AppData\Local\Temp\ipykernel_36240\4140904624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optionsData['date'] = pd.to_datetime(optionsData['date'])

# %%
optionsData['underlyingTicker'] = optionsData['source_file'].str.split('_').str[0]
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_36240\1530006188.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optionsData['underlyingTicker'] = optionsData['source_file'].str.split('_').str[0]

# %%
optionsData['expiration'] = pd.to_datetime(optionsData['expiration'])
# Out:
# C:\Users\H P\AppData\Local\Temp\ipykernel_36240\1268630523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optionsData['expiration'] = pd.to_datetime(optionsData['expiration'])

# %%
start_date = pd.to_datetime('2025-09-12')
last_date = pd.to_datetime('2025-12-12')

optionsData = optionsData[optionsData['date'] >= start_date]
optionsData = optionsData[optionsData['date'] <= last_date]

# %%
optionsData['timeToMaturity'] = (optionsData['expiration'] - optionsData['date']).dt.days/365.25
optionsData = optionsData[optionsData['timeToMaturity'] != 0]

# %% [markdown]
# ##### Handle Put-Call Ratio (PCR) data

# %%
df = optionsData

# %%
pivot = df.pivot_table(index='date', columns='optionType', values='volume', aggfunc='sum').reset_index()

pivot['PCR'] = pivot.apply(lambda row: row['put']/row['call'] if row['call'] != 0 else None, axis=1)

pivot[['date','call','put','PCR']]
# Out:
# optionType       date          call           put     PCR
# 0          2025-09-12 4837453.00000 1717121.00000 0.35496
# 1          2025-09-15 4163745.00000 1928605.00000 0.46319
# 2          2025-09-16 3318339.00000 1414823.00000 0.42636
# 3          2025-09-17 3459169.00000 1893364.00000 0.54735
# 4          2025-09-18 3948063.00000 2105354.00000 0.53326
# ..                ...           ...           ...     ...
# 60         2025-12-08 2535660.00000 1481496.00000 0.58426
# 61         2025-12-09   31000.00000   60932.00000 1.96555
# 62         2025-12-10 2824790.00000 1371552.00000 0.48554
# 63         2025-12-11   33805.00000   51771.00000 1.53146
# 64         2025-12-12 3366108.00000 1453783.00000 0.43189
#
# [65 rows x 4 columns]

# %%
pivot = pivot.drop(['call','put'], axis=1)
pivot
# Out:
# optionType       date     PCR
# 0          2025-09-12 0.35496
# 1          2025-09-15 0.46319
# 2          2025-09-16 0.42636
# 3          2025-09-17 0.54735
# 4          2025-09-18 0.53326
# ..                ...     ...
# 60         2025-12-08 0.58426
# 61         2025-12-09 1.96555
# 62         2025-12-10 0.48554
# 63         2025-12-11 1.53146
# 64         2025-12-12 0.43189
#
# [65 rows x 2 columns]

# %%
pivot.describe()
# Out:
# optionType                           date      PCR
# count                                  65 65.00000
# mean        2025-10-27 19:56:18.461538560  0.59933
# min                   2025-09-12 00:00:00  0.35496
# 25%                   2025-10-06 00:00:00  0.48206
# 50%                   2025-10-28 00:00:00  0.52169
# 75%                   2025-11-19 00:00:00  0.56824
# max                   2025-12-12 00:00:00  2.42395
# std                                   NaN  0.33282

# %%
optionsData = optionsData.merge(pivot, on='date', how='left')

# %%
optionsData.columns
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency',
#        'expiration', 'source_file', 'optionType', 'date', 'underlyingTicker',
#        'timeToMaturity', 'PCR'],
#       dtype='object')

# %% [markdown]
# ##### Handle Google Search (GS) Trend data

# %%
gs_folder = "./google search trends data/"

# %%
gs_data_tech = pd.read_csv(gs_folder + "Technology.csv")
gs_data_auto = pd.read_csv(gs_folder + "Automobile.csv")

# %%
gs_data_tech['date'] = pd.to_datetime(gs_data_tech['date'])
gs_data_auto['date'] = pd.to_datetime(gs_data_auto['date'])

# %%
optionsData = optionsData.merge(gs_data_tech, on='date', how='left')
optionsData = optionsData.merge(gs_data_auto, on='date', how='left')

# %%
def get_google_search_trends(row):
    ticker = row['underlyingTicker']
    return row["GS_" + ticker]

optionsData['GS'] = optionsData.apply(get_google_search_trends, axis=1)

# %% [markdown]
# ##### Handle news Sentiment Score (SC) data

# %%
sc_folder = "./gdelt news data/"

# %%
news_sentiment_score = pd.read_csv(sc_folder + "news_sentiment_score.csv")
news_sentiment_score['date'] = pd.to_datetime(news_sentiment_score['date'])

optionsData = optionsData.merge(news_sentiment_score, on='date', how='left')

# %%
optionsData.columns
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        'impliedVolatility', 'inTheMoney', 'contractSize', 'currency',
#        'expiration', 'source_file', 'optionType', 'date', 'underlyingTicker',
#        'timeToMaturity', 'PCR', 'GS_BAC', 'GS_C', 'GS_GS', 'GS_JPM', 'GS_WFC',
#        'GS_AAPL', 'GS_AMZN', 'GS_GOOGL', 'GS_META', 'GS_MSFT', 'GS_F', 'GS_GM',
#        'GS_LCID', 'GS_RIVN', 'GS_TSLA', 'GS_ABBV', 'GS_JNJ', 'GS_MRK',
#        'GS_PFE', 'GS_UNH', 'GS', 'SC_AAPL', 'SC_AMZN', 'SC_GOOGL', 'SC_META',
#        'SC_MSFT', 'SC_BAC', 'SC_C', 'SC_GS', 'SC_JPM', 'SC_WFC', 'SC_ABBV',
#        'SC_JNJ', 'SC_MRK', 'SC_PFE', 'SC_UNH', 'SC_F', 'SC_GM', 'SC_LCID',
#        'SC_RIVN', 'SC_TSLA'],
#       dtype='object')

# %%
def get_underlying_sentiment_score_from(row):
    ticker = row['underlyingTicker']
    return row["SC_" + ticker]

optionsData['SC'] = optionsData.apply(get_underlying_sentiment_score_from, axis=1)

# %%
optionsData["SC"]
# Out:
# 0         0.10283
# 1         0.10283
# 2         0.10283
# 3         0.10283
# 4         0.10283
#             ...
# 1088555   0.07455
# 1088556   0.07443
# 1088557   0.07455
# 1088558   0.05093
# 1088559   0.07455
# Name: SC, Length: 1088560, dtype: float64

# %% [markdown]
# ##### Extract Underlings historical data, VIX, and Interest Rate historical datas

# %%
indices_and_equities_underlyings_ticker = TechnologyUnderlying + AutomobileUnderlying + ["^VIX", "^IRX"]
indices_and_equities_values = {}

for ticker in indices_and_equities_underlyings_ticker:
      data = yf.download(ticker, start=start_date, end=last_date)
      indices_and_equities_values[ticker] = data["Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for ticker in indices_and_equities_values:
  temp = indices_and_equities_values[ticker]
  temp = temp.reset_index()
  temp.columns=['date', ticker]
  optionsData = optionsData.merge(temp, on='date', how='left')

# %%
optionsData.columns
#optionsData = optionsData.drop(["GS_x"], axis=1)
# Out:
# Index(['contractSymbol', 'lastTradeDate', 'strike', 'lastPrice', 'bid', 'ask',
#        'change', 'percentChange', 'volume', 'openInterest',
#        ...
#        'MRK_y', 'PFE_y', 'UNH_y', 'F_y', 'GM_y', 'LCID_y', 'RIVN_y', 'TSLA_y',
#        '^VIX_y', '^IRX_y'],
#       dtype='object', length=105)

# %%
def get_underlying_last_price(row):
    ticker = row['underlyingTicker']
    print(ticker)
    return row[ticker]

optionsData['underlyingLastPrice'] = optionsData.apply(get_underlying_last_price, axis=1)

# %%
optionsData.rename(columns={
    '^IRX': 'riskFreeRate',
    "^VIX": "VIX"
}, inplace=True)

optionsData['riskFreeRate'] = optionsData["riskFreeRate"] / 100
optionsData['impliedVolatility'] = optionsData["impliedVolatility"] / 100

# %%
optionsData["riskFreeRate"].describe()
# Out:
# count   590216.00000
# mean         0.03589
# std          0.00009
# min          0.03570
# 25%          0.03582
# 50%          0.03590
# 75%          0.03595
# max          0.03605
# Name: riskFreeRate, dtype: float64

# %% [markdown]
# ##### Save dataset

# %%
from sklearn.model_selection import train_test_split

list_underlyings = [
    "AAPL",
    "AMZN",
    "GOOGL",
    "META",
    "MSFT",
    "F",
    "GM",
    "LCID",
    "RIVN",
    "TSLA"
]

# %%
for ticker in list_underlyings:
      columns_to_keep = [
      "date",
      "lastTradeDate",
      "timeToMaturity",
      "underlyingLastPrice",
      "riskFreeRate",
      "lastPrice",
      "impliedVolatility",
      "strike",
      "PCR",
      "VIX",
      "GS_" + ticker,
      "SC_" + ticker
      ]
      data = optionsData[optionsData["underlyingTicker"] == ticker]
      data = data[[col for col in columns_to_keep if col in data.columns]]
      
      train_data, test_data = train_test_split(data, test_size=0.2, random_state=42 )
      train_data.to_csv("./prepocessed options datas/" + ticker + '_train.csv')
      test_data.to_csv("./prepocessed options datas/"  + ticker + '_test.csv')
